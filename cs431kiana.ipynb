    "10-08-2020", "10-08-2021", "10-08-2022",
    "10-09-2020", "10-09-2021", "10-09-2022",
    "10-10-2020", "10-10-2021", "10-10-2022",
    "10-11-2020", "10-11-2021", "10-11-2022",
    "10-12-2020", "10-12-2021", "10-12-2022",
    "10-13-2020", "10-13-2021", "10-13-2022",
    "10-14-2020", "10-14-2021", "10-14-2022",
    "10-15-2020", "10-15-2021", "10-15-2022",
    "10-16-2020", "10-16-2021", "10-16-2022",
    "10-17-2020", "10-17-2021", "10-17-2022",
    "10-18-2020", "10-18-2021", "10-18-2022",
    "10-19-2020", "10-19-2021", "10-19-2022",
    "10-20-2020", "10-20-2021", "10-20-2022",
    "10-21-2020", "10-21-2021", "10-21-2022",
    "10-22-2020", "10-22-2021", "10-22-2022",
    "10-23-2020", "10-23-2021", "10-23-2022",
    "10-24-2020", "10-24-2021", "10-24-2022",
    "10-25-2020", "10-25-2021", "10-25-2022",
    "10-26-2020", "10-26-2021", "10-26-2022",
    "10-27-2020", "10-27-2021", "10-27-2022",
    "10-28-2020", "10-28-2021", "10-28-2022",
    "10-29-2020", "10-29-2021", "10-29-2022",
    "10-30-2020", "10-30-2021", "10-30-2022",
    "10-31-2020", "10-31-2021", "10-31-2022",
    "11-01-2020", "11-01-2021", "11-01-2022",
    "11-02-2020", "11-02-2021", "11-02-2022",
    "11-03-2020", "11-03-2021", "11-03-2022",
    "11-04-2020", "11-04-2021", "11-04-2022",
    "11-05-2020", "11-05-2021", "11-05-2022",
    "11-06-2020", "11-06-2021", "11-06-2022",
    "11-07-2020", "11-07-2021", "11-07-2022",
    "11-08-2020", "11-08-2021", "11-08-2022",
    "11-09-2020", "11-09-2021", "11-09-2022",
    "11-10-2020", "11-10-2021", "11-10-2022",
    "11-11-2020", "11-11-2021", "11-11-2022",
    "11-12-2020", "11-12-2021", "11-12-2022",
    "11-13-2020", "11-13-2021", "11-13-2022",
]

df_list = []

for date in dates:
    url = f"{the_base_url}{date}.csv"  
    try:
        temporary_df = pd.read_csv(url)  
        temporary_df["Date"] = pd.to_datetime(date, format="%m-%d-%Y")  
        df_list.append(temporary_df)
        print(f"Loaded {date}.csv successfully.")
    except Exception as e:
        print(f"Error loading this csv {date}.csv: {e}")


if df_list:
    df = pd.concat(df_list, ignore_index=True)
    print("CSV files merged successfully.")
    print(df.head())
else:
    print("No data was loaded :(.")
# Out:
# Loaded 01-01-2021.csv successfully.
# Loaded 01-01-2022.csv successfully.
# Loaded 01-01-2023.csv successfully.
# Loaded 01-02-2021.csv successfully.
# Loaded 01-02-2022.csv successfully.
# Loaded 01-02-2023.csv successfully.
# Loaded 01-03-2021.csv successfully.
# Loaded 01-03-2022.csv successfully.
# Loaded 01-03-2023.csv successfully.
# Loaded 01-04-2021.csv successfully.
# Loaded 01-04-2022.csv successfully.
# Loaded 01-04-2023.csv successfully.
# Loaded 01-05-2021.csv successfully.
# Loaded 01-05-2022.csv successfully.
# Loaded 01-05-2023.csv successfully.
# Loaded 01-06-2021.csv successfully.
# Loaded 01-06-2022.csv successfully.
# Loaded 01-06-2023.csv successfully.
# Loaded 01-07-2021.csv successfully.
# Loaded 01-07-2022.csv successfully.
# Loaded 01-07-2023.csv successfully.
# Loaded 01-08-2021.csv successfully.
# Loaded 01-08-2022.csv successfully.
# Loaded 01-08-2023.csv successfully.
# Loaded 01-09-2021.csv successfully.
# Loaded 01-09-2022.csv successfully.
# ...

# %%
m = df.isnull().sum()
print(m)
# Out:
# FIPS                    676551
# Admin2                  672428
# Province_State          176990
# Country_Region            9349
# Last_Update               9349
# Lat                      90368
# Long_                    90368
# Confirmed                   28
# Deaths                     433
# Recovered              2435330
# Active                 2444295
# Combined_Key              9349
# Incident_Rate           938848
# Case_Fatality_Ratio     904540
# Date                         0
# Province/State         3691085
# Country/Region         3687550
# Last Update            3687550
# Latitude               3691407
# Longitude              3691407
# Incidence_Rate         3062925
# Case-Fatality_Ratio    3059416
# dtype: int64

# %%
df.columns
# Out:
# Index(['FIPS', 'Admin2', 'Province_State', 'Country_Region', 'Last_Update',
#        'Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'Combined_Key', 'Incident_Rate', 'Case_Fatality_Ratio', 'Date',
#        'Province/State', 'Country/Region', 'Last Update', 'Latitude',
#        'Longitude', 'Incidence_Rate', 'Case-Fatality_Ratio'],
#       dtype='object')

# %%
df.head()
# Out:
#    FIPS Admin2 Province_State Country_Region          Last_Update       Lat  \
# 0   NaN    NaN            NaN    Afghanistan  2021-01-02 05:22:33  33.93911
# 1   NaN    NaN            NaN        Albania  2021-01-02 05:22:33  41.15330
# 2   NaN    NaN            NaN        Algeria  2021-01-02 05:22:33  28.03390
# 3   NaN    NaN            NaN        Andorra  2021-01-02 05:22:33  42.50630
# 4   NaN    NaN            NaN         Angola  2021-01-02 05:22:33 -11.20270
#
#        Long_  Confirmed  Deaths  Recovered  ...  Incident_Rate  \
# 0  67.709953    52513.0  2201.0    41727.0  ...     134.896578
# 1  20.168300    58316.0  1181.0    33634.0  ...    2026.409062
# 2   1.659600    99897.0  2762.0    67395.0  ...     227.809861
# 3   1.521800     8117.0    84.0     7463.0  ...   10505.403482
# 4  17.873900    17568.0   405.0    11146.0  ...      53.452981
#
#   Case_Fatality_Ratio       Date  Province/State Country/Region Last Update  \
# ...

# %%
print(df[['Lat', 'Latitude']].dropna().head(10))
print(df[['Long_', 'Longitude']].dropna().head(10))
# Out:
# Empty DataFrame
# Columns: [Lat, Latitude]
# Index: []
# Empty DataFrame
# Columns: [Long_, Longitude]
# Index: []

# %%
# df.columns[df.columns.duplicated()]

# %%
print(df.columns[df.columns.duplicated()])
# Out:
# Index([], dtype='object')

# %%
df.drop(columns=['Latitude', 'Longitude'], inplace=True)

# %%
df.columns
# Out:
# Index(['FIPS', 'Admin2', 'Province_State', 'Country_Region', 'Last_Update',
#        'Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'Combined_Key', 'Incident_Rate', 'Case_Fatality_Ratio', 'Date',
#        'Province/State', 'Country/Region', 'Last Update', 'Incidence_Rate',
#        'Case-Fatality_Ratio'],
#       dtype='object')

# %%
df.head()
# Out:
#    FIPS Admin2 Province_State Country_Region          Last_Update       Lat  \
# 0   NaN    NaN            NaN    Afghanistan  2021-01-02 05:22:33  33.93911
# 1   NaN    NaN            NaN        Albania  2021-01-02 05:22:33  41.15330
# 2   NaN    NaN            NaN        Algeria  2021-01-02 05:22:33  28.03390
# 3   NaN    NaN            NaN        Andorra  2021-01-02 05:22:33  42.50630
# 4   NaN    NaN            NaN         Angola  2021-01-02 05:22:33 -11.20270
#
#        Long_  Confirmed  Deaths  Recovered   Active Combined_Key  \
# 0  67.709953    52513.0  2201.0    41727.0   8585.0  Afghanistan
# 1  20.168300    58316.0  1181.0    33634.0  23501.0      Albania
# 2   1.659600    99897.0  2762.0    67395.0  29740.0      Algeria
# 3   1.521800     8117.0    84.0     7463.0    570.0      Andorra
# 4  17.873900    17568.0   405.0    11146.0   6017.0       Angola
#
#    Incident_Rate  Case_Fatality_Ratio       Date Province/State  \
# ...

# %%
df.drop(columns=['Province/State', 'Country/Region', 'Last Update', 'Case-Fatality_Ratio'], inplace=True, errors='ignore')

# %%
df.head()
# Out:
#    FIPS Admin2 Province_State Country_Region          Last_Update       Lat  \
# 0   NaN    NaN            NaN    Afghanistan  2021-01-02 05:22:33  33.93911
# 1   NaN    NaN            NaN        Albania  2021-01-02 05:22:33  41.15330
# 2   NaN    NaN            NaN        Algeria  2021-01-02 05:22:33  28.03390
# 3   NaN    NaN            NaN        Andorra  2021-01-02 05:22:33  42.50630
# 4   NaN    NaN            NaN         Angola  2021-01-02 05:22:33 -11.20270
#
#        Long_  Confirmed  Deaths  Recovered   Active Combined_Key  \
# 0  67.709953    52513.0  2201.0    41727.0   8585.0  Afghanistan
# 1  20.168300    58316.0  1181.0    33634.0  23501.0      Albania
# 2   1.659600    99897.0  2762.0    67395.0  29740.0      Algeria
# 3   1.521800     8117.0    84.0     7463.0    570.0      Andorra
# 4  17.873900    17568.0   405.0    11146.0   6017.0       Angola
#
#    Incident_Rate  Case_Fatality_Ratio       Date  Incidence_Rate
# ...

# %%
df[['Province_State', 'Province_State']].dropna().head()
# Out:
#                   Province_State                Province_State
# 8   Australian Capital Territory  Australian Capital Territory
# 9                New South Wales               New South Wales
# 10            Northern Territory            Northern Territory
# 11                    Queensland                    Queensland
# 12               South Australia               South Australia

# %%
unknown_count = (df['Province_State'] == "Unknown").sum()
print("Number of 'Unknown' values:", unknown_count)

non_unknown_count = (df['Province_State'] != "Unknown").sum()
print("Number of values that are NOT 'Unknown':", non_unknown_count)
# Out:
# Number of 'Unknown' values: 12037
# Number of values that are NOT 'Unknown': 3684862

# %%
print(df[['Incident_Rate', 'Incidence_Rate']].head(10))  
are_identical = df['Incident_Rate'].equals(df['Incidence_Rate'])
print("Are the two columns identical?", are_identical)
# Out:
#    Incident_Rate  Incidence_Rate
# 0     134.896578             NaN
# 1    2026.409062             NaN
# 2     227.809861             NaN
# 3   10505.403482             NaN
# 4      53.452981             NaN
# 5     162.364186             NaN
# 6    3605.633332             NaN
# 7    5390.664389             NaN
# 8      27.563653             NaN
# 9      60.938655             NaN
# Are the two columns identical? False

# %%
print(df['Incidence_Rate'].nunique()) 
print(df['Incidence_Rate'].value_counts())
# Out:
# 430461
# Incidence_Rate
# 0.000000      5180
# 373.241459     166
# 1.041283       165
# 0.303851       165
# 0.027412       165
#               ...
# 94.039958        1
# 18.158547        1
# 178.362573       1
# 987.927565       1
# 182.925280       1
# Name: count, Length: 430461, dtype: int64

# %%
df.drop(columns=['Incidence_Rate'], inplace=True)

# %%
print("Unique values in Country_Region:", df['Country_Region'].nunique())
print("Unique values in Combined_Key:", df['Combined_Key'].nunique())
# Out:
# Unique values in Country_Region: 202
# Unique values in Combined_Key: 4164

# %%
df.columns.value_counts()
# Out:
# FIPS                   1
# Admin2                 1
# Province_State         1
# Country_Region         1
# Last_Update            1
# Lat                    1
# Long_                  1
# Confirmed              1
# Deaths                 1
# Recovered              1
# Active                 1
# Combined_Key           1
# Incident_Rate          1
# Case_Fatality_Ratio    1
# Date                   1
# Name: count, dtype: int64

# %%
df = df.loc[:, ~df.columns.duplicated()]
df.columns
# Out:
# Index(['FIPS', 'Admin2', 'Province_State', 'Country_Region', 'Last_Update',
#        'Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'Combined_Key', 'Incident_Rate', 'Case_Fatality_Ratio', 'Date'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# FIPS                    676551
# Admin2                  672428
# Province_State          176990
# Country_Region            9349
# Last_Update               9349
# Lat                      90368
# Long_                    90368
# Confirmed                   28
# Deaths                     433
# Recovered              2435330
# Active                 2444295
# Combined_Key              9349
# Incident_Rate           938848
# Case_Fatality_Ratio     904540
# Date                         0
# dtype: int64

# %%
def analyze_df(df, head_rows=5):
    print(f"1. First {head_rows} rows of data:\n")
    display(df.head())

    print(f"\n 2. Data Info:\n")
    display(df.info())

    print(f"\n 3. Description of Data:\n")
    display(df.describe().transpose())

    print(f" 4. Missing Values: \n")
    missing_values = df.isnull().sum()
    display(missing_values)

# %%
analyze_df(df, head_rows=5)
# Out:
# 1. First 5 rows of data:
#    FIPS Admin2 Province_State Country_Region          Last_Update       Lat  \
# 0   NaN    NaN            NaN    Afghanistan  2021-01-02 05:22:33  33.93911
# 1   NaN    NaN            NaN        Albania  2021-01-02 05:22:33  41.15330
# 2   NaN    NaN            NaN        Algeria  2021-01-02 05:22:33  28.03390
# 3   NaN    NaN            NaN        Andorra  2021-01-02 05:22:33  42.50630
# 4   NaN    NaN            NaN         Angola  2021-01-02 05:22:33 -11.20270
#
#        Long_  Confirmed  Deaths  Recovered   Active Combined_Key  \
# 0  67.709953    52513.0  2201.0    41727.0   8585.0  Afghanistan
# 1  20.168300    58316.0  1181.0    33634.0  23501.0      Albania
# 2   1.659600    99897.0  2762.0    67395.0  29740.0      Algeria
# 3   1.521800     8117.0    84.0     7463.0    570.0      Andorra
# 4  17.873900    17568.0   405.0    11146.0   6017.0       Angola
#
#    Incident_Rate  Case_Fatality_Ratio       Date
# ...

# %%
dup = df.duplicated().sum()
print(dup)
# Out:
# 16640

# %%
df = df.drop_duplicates()

# %%
dup = df.duplicated().sum()
print(dup)
# Out:
# 0

# %%
print(df.head())
# Out:
#    FIPS Admin2 Province_State Country_Region          Last_Update       Lat  \
# 0   NaN    NaN            NaN    Afghanistan  2021-01-02 05:22:33  33.93911
# 1   NaN    NaN            NaN        Albania  2021-01-02 05:22:33  41.15330
# 2   NaN    NaN            NaN        Algeria  2021-01-02 05:22:33  28.03390
# 3   NaN    NaN            NaN        Andorra  2021-01-02 05:22:33  42.50630
# 4   NaN    NaN            NaN         Angola  2021-01-02 05:22:33 -11.20270
#
#        Long_  Confirmed  Deaths  Recovered   Active Combined_Key  \
# 0  67.709953    52513.0  2201.0    41727.0   8585.0  Afghanistan
# 1  20.168300    58316.0  1181.0    33634.0  23501.0      Albania
# 2   1.659600    99897.0  2762.0    67395.0  29740.0      Algeria
# 3   1.521800     8117.0    84.0     7463.0    570.0      Andorra
# 4  17.873900    17568.0   405.0    11146.0   6017.0       Angola
#
#    Incident_Rate  Case_Fatality_Ratio       Date
# 0     134.896578             4.191343 2021-01-01
# ...

# %%
print(df.isnull().sum())
# Out:
# FIPS                    669706
# Admin2                  665597
# Province_State          171836
# Country_Region            4729
# Last_Update               4729
# Lat                      85484
# Long_                    85484
# Confirmed                   10
# Deaths                     252
# Recovered              2427150
# Active                 2431677
# Combined_Key              4729
# Incident_Rate           930054
# Case_Fatality_Ratio     895846
# Date                         0
# dtype: int64

# %%
df.head()
# Out:
#    FIPS Admin2 Province_State Country_Region          Last_Update       Lat  \
# 0   NaN    NaN            NaN    Afghanistan  2021-01-02 05:22:33  33.93911
# 1   NaN    NaN            NaN        Albania  2021-01-02 05:22:33  41.15330
# 2   NaN    NaN            NaN        Algeria  2021-01-02 05:22:33  28.03390
# 3   NaN    NaN            NaN        Andorra  2021-01-02 05:22:33  42.50630
# 4   NaN    NaN            NaN         Angola  2021-01-02 05:22:33 -11.20270
#
#        Long_  Confirmed  Deaths  Recovered   Active Combined_Key  \
# 0  67.709953    52513.0  2201.0    41727.0   8585.0  Afghanistan
# 1  20.168300    58316.0  1181.0    33634.0  23501.0      Albania
# 2   1.659600    99897.0  2762.0    67395.0  29740.0      Algeria
# 3   1.521800     8117.0    84.0     7463.0    570.0      Andorra
# 4  17.873900    17568.0   405.0    11146.0   6017.0       Angola
#
#    Incident_Rate  Case_Fatality_Ratio       Date
# 0     134.896578             4.191343 2021-01-01
# ...

# %%
df.loc[:, "Province_State"] = df["Province_State"].fillna("Unknown")
print("Filled missing Province_State with 'Unknown' because many countries don't have states.")
# Out:
# Filled missing Province_State with 'Unknown' because many countries don't have states.

# %%
print(df.isnull().sum())
# Out:
# FIPS                    669706
# Admin2                  665597
# Province_State               0
# Country_Region            4729
# Last_Update               4729
# Lat                      85484
# Long_                    85484
# Confirmed                   10
# Deaths                     252
# Recovered              2427150
# Active                 2431677
# Combined_Key              4729
# Incident_Rate           930054
# Case_Fatality_Ratio     895846
# Date                         0
# dtype: int64

# %%
df.loc[:, "Country_Region"] = df["Country_Region"].fillna("Unknown")
print("Filled missing Country_Region with 'Unknown'. This column is critical, if we don't have it, there is no particular use for it.")
# Out:
# Filled missing Country_Region with 'Unknown'. This column is critical, if we don't have it, there is no particular use for it.

# %%
df.loc[:,"Last_Update"] = df["Last_Update"].fillna("Date")
print("Filled missing Last_Update using Date.")
# Out:
# Filled missing Last_Update using Date.

# %%
print(df.isnull().sum())
# Out:
# FIPS                    669706
# Admin2                  665597
# Province_State               0
# Country_Region               0
# Last_Update                  0
# Lat                      85484
# Long_                    85484
# Confirmed                   10
# Deaths                     252
# Recovered              2427150
# Active                 2431677
# Combined_Key              4729
# Incident_Rate           930054
# Case_Fatality_Ratio     895846
# Date                         0
# dtype: int64

# %%
df.loc[:, "Lat"] = df["Lat"].fillna(
    df.groupby("Province_State")["Lat"].transform("median")
)
df.loc[:, "Long_"] = df["Long_"].fillna(
    df.groupby("Province_State")["Long_"].transform("median")
)
print("Filled missing Latitude and Longitude using Province_State median.")
# Out:
# Filled missing Latitude and Longitude using Province_State median.

# %%
print(df.isnull().sum())
# Out:
# FIPS                    669706
# Admin2                  665597
# Province_State               0
# Country_Region               0
# Last_Update                  0
# Lat                       1564
# Long_                     1564
# Confirmed                   10
# Deaths                     252
# Recovered              2427150
# Active                 2431677
# Combined_Key              4729
# Incident_Rate           930054
# Case_Fatality_Ratio     895846
# Date                         0
# dtype: int64

# %%
print(df[df["Lat"].isnull()][["Province_State", "Country_Region"]].value_counts())
# Out:
# Province_State          Country_Region
# Port Quarantine         Japan             866
# Repatriated Travellers  Canada            696
# Jervis Bay Territory    Australia           1
# External territories    Australia           1
# Name: count, dtype: int64

# %%
df.loc[:, "Lat"] = df["Lat"].fillna(
    df.groupby("Country_Region")["Lat"].transform("median")
)
df.loc[:, "Long_"] = df["Long_"].fillna(
    df.groupby("Country_Region")["Long_"].transform("median")
)
print("Filled missing Latitude and Longitude using Country_Region median.")
# Out:
# Filled missing Latitude and Longitude using Country_Region median.

# %%
print(df.isnull().sum())
# Out:
# FIPS                    669706
# Admin2                  665597
# Province_State               0
# Country_Region               0
# Last_Update                  0
# Lat                          0
# Long_                        0
# Confirmed                   10
# Deaths                     252
# Recovered              2427150
# Active                 2431677
# Combined_Key              4729
# Incident_Rate           930054
# Case_Fatality_Ratio     895846
# Date                         0
# dtype: int64

# %%
print(df.isnull().sum() / len(df) * 100)
# Out:
# FIPS                   18.197252
# Admin2                 18.085602
# Province_State          0.000000
# Country_Region          0.000000
# Last_Update             0.000000
# Lat                     0.000000
# Long_                   0.000000
# Confirmed               0.000272
# Deaths                  0.006847
# Recovered              65.950521
# Active                 66.073529
# Combined_Key            0.128496
# Incident_Rate          25.271428
# Case_Fatality_Ratio    24.341928
# Date                    0.000000
# dtype: float64

# %%
# df = df.dropna(subset=["Latitude", "Longitude"])
# print("Dropped rows where Latitude or Longitude was missing.")

# %%
df.loc[:, "Combined_Key"] = df["Combined_Key"].fillna(
    df["Province_State"] + ", " + df["Country_Region"]
)
print("Filled missing Combined_Key using Province_State and Country_Region.")
# Out:
# Filled missing Combined_Key using Province_State and Country_Region.

# %%
print(df.isnull().sum())
# Out:
# FIPS                    669706
# Admin2                  665597
# Province_State               0
# Country_Region               0
# Last_Update                  0
# Lat                          0
# Long_                        0
# Confirmed                   10
# Deaths                     252
# Recovered              2427150
# Active                 2431677
# Combined_Key                 0
# Incident_Rate           930054
# Case_Fatality_Ratio     895846
# Date                         0
# dtype: int64

# %%
df["Incident_Rate"] = df["Incident_Rate"].fillna(df["Incident_Rate"].median())
print("Filled missing Incidence_Rate with median value.")
# Out:
# Filled missing Incidence_Rate with median value.

# %%
print(df.isnull().sum())
# Out:
# FIPS                    669706
# Admin2                  665597
# Province_State               0
# Country_Region               0
# Last_Update                  0
# Lat                          0
# Long_                        0
# Confirmed                   10
# Deaths                     252
# Recovered              2427150
# Active                 2431677
# Combined_Key                 0
# Incident_Rate                0
# Case_Fatality_Ratio     895846
# Date                         0
# dtype: int64

# %%
print(df.isnull().sum() / len(df) * 100)
# Out:
# FIPS                   18.197252
# Admin2                 18.085602
# Province_State          0.000000
# Country_Region          0.000000
# Last_Update             0.000000
# Lat                     0.000000
# Long_                   0.000000
# Confirmed               0.000272
# Deaths                  0.006847
# Recovered              65.950521
# Active                 66.073529
# Combined_Key            0.000000
# Incident_Rate           0.000000
# Case_Fatality_Ratio    24.341928
# Date                    0.000000
# dtype: float64

# %%
print("Number of non-null FIPS codes:", df['FIPS'].notna().sum())
print(df['FIPS'].dropna().head(10)) 
print(df[['FIPS', 'Country_Region', 'Province_State']].dropna().head(10))
# Out:
# Number of non-null FIPS codes: 3010553
# 648    1001.0
# 649    1003.0
# 650    1005.0
# 651    1007.0
# 652    1009.0
# 653    1011.0
# 654    1013.0
# 655    1015.0
# 656    1017.0
# 657    1019.0
# Name: FIPS, dtype: float64
#        FIPS Country_Region Province_State
# 648  1001.0             US        Alabama
# 649  1003.0             US        Alabama
# 650  1005.0             US        Alabama
# 651  1007.0             US        Alabama
# 652  1009.0             US        Alabama
# 653  1011.0             US        Alabama
# 654  1013.0             US        Alabama
# 655  1015.0             US        Alabama
# 656  1017.0             US        Alabama
# 657  1019.0             US        Alabama

# %%
# Fill in FIPS data 
fips_url = "https://raw.githubusercontent.com/kjhealy/fips-codes/master/state_and_county_fips_master.csv"
fips_mapping = pd.read_csv(fips_url)
print(fips_mapping.head())
# Out:
#    fips            name state
# 0     0   UNITED STATES   NaN
# 1  1000         ALABAMA   NaN
# 2  1001  Autauga County    AL
# 3  1003  Baldwin County    AL
# 4  1005  Barbour County    AL

# %%
df.head()
# Out:
#    FIPS Admin2 Province_State Country_Region          Last_Update       Lat  \
# 0   NaN    NaN        Unknown    Afghanistan  2021-01-02 05:22:33  33.93911
# 1   NaN    NaN        Unknown        Albania  2021-01-02 05:22:33  41.15330
# 2   NaN    NaN        Unknown        Algeria  2021-01-02 05:22:33  28.03390
# 3   NaN    NaN        Unknown        Andorra  2021-01-02 05:22:33  42.50630
# 4   NaN    NaN        Unknown         Angola  2021-01-02 05:22:33 -11.20270
#
#        Long_  Confirmed  Deaths  Recovered   Active Combined_Key  \
# 0  67.709953    52513.0  2201.0    41727.0   8585.0  Afghanistan
# 1  20.168300    58316.0  1181.0    33634.0  23501.0      Albania
# 2   1.659600    99897.0  2762.0    67395.0  29740.0      Algeria
# 3   1.521800     8117.0    84.0     7463.0    570.0      Andorra
# 4  17.873900    17568.0   405.0    11146.0   6017.0       Angola
#
#    Incident_Rate  Case_Fatality_Ratio       Date
# 0     134.896578             4.191343 2021-01-01
# ...

# %%
df['FIPS'] = df['FIPS'].astype('Int64')

# %%
fips_mapping['fips'] = fips_mapping['fips'].astype('Int64')

# %%
missing_fips_list = df[~df['FIPS'].isin(fips_mapping['fips'])]
print("Total FIPS codes in dataset that are missing from GitHub:", len(missing_fips_list))
print(missing_fips_list[['FIPS', 'Province_State']].head(10))
# Out:
# Total FIPS codes in dataset that are missing from GitHub: 801237
#    FIPS                Province_State
# 0  <NA>                       Unknown
# 1  <NA>                       Unknown
# 2  <NA>                       Unknown
# 3  <NA>                       Unknown
# 4  <NA>                       Unknown
# 5  <NA>                       Unknown
# 6  <NA>                       Unknown
# 7  <NA>                       Unknown
# 8  <NA>  Australian Capital Territory
# 9  <NA>               New South Wales

# %%
print(df['Country_Region'].value_counts().head(20))
# Out:
# Country_Region
# US                3020805
# Russia              71617
# Japan               42450
# China               31722
# India               31593
# Colombia            29452
# Mexico              28725
# Ukraine             24278
# Brazil              23676
# Peru                22583
# Italy               18533
# Sweden              18093
# United Kingdom      17693
# Spain               17648
# Malaysia            15861
# Germany             15013
# Chile               14917
# Canada              14712
# Netherlands         14446
# France              10942
# Name: count, dtype: int64

# %%
# Keeping only US data

# %%
df_us = df[df['Country_Region'] == "US"].copy()

# %%
print(df_us['Country_Region'].value_counts())
# Out:
# Country_Region
# US    3020805
# Name: count, dtype: int64

# %%
print("Original dataset shape:", df.shape)  
print("Filtered U.S. dataset shape:", df_us.shape)
# Out:
# Original dataset shape: (3680259, 15)
# Filtered U.S. dataset shape: (3020805, 15)

# %%
df_us.reset_index(drop=True, inplace=True)

# %%
print(df_us.sample(10))
# Out:
#           FIPS     Admin2  Province_State Country_Region          Last_Update  \
# 2831707  20205     Wilson          Kansas             US  2022-10-26 04:22:19
# 943636   48245  Jefferson           Texas             US  2020-04-14 23:33:31
# 2554612  45047  Greenwood  South Carolina             US  2021-09-28 04:21:28
# 915962   16061      Lewis           Idaho             US  2020-04-11 22:45:33
# 2905527  48135      Ector           Texas             US  2020-11-03 06:00:16
# 2335002  72029  Canovanas     Puerto Rico             US  2020-09-06 04:28:33
# 730925   55135    Waupaca       Wisconsin             US        3/22/20 23:45
# 2863330  54033   Harrison   West Virginia             US  2022-10-29 04:21:13
# 1283685  31043     Dakota        Nebraska             US  2020-05-21 02:32:48
# 1108352   1049     DeKalb         Alabama             US  2022-05-02 04:21:10
#
#                Lat       Long_  Confirmed  Deaths  Recovered  Active  \
# ...

# %%
df_us = df_us.merge(fips_mapping[['fips', 'state', 'name']], 
                    left_on='FIPS',   
                    right_on='fips',  
                    how='left')

df_us.drop(columns=['fips'], inplace=True)

# %%
print(df_us.columns)
# Out:
# Index(['FIPS', 'Admin2', 'Province_State', 'Country_Region', 'Last_Update',
#        'Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'Combined_Key', 'Incident_Rate', 'Case_Fatality_Ratio', 'Date', 'state',
#        'name'],
#       dtype='object')

# %%
print("Missing values in state column:", df_us['state'].isna().sum())
print("Missing values in name column:", df_us['name'].isna().sum())
# Out:
# Missing values in state column: 141783
# Missing values in name column: 141783

# %%
print(df_us[['FIPS', 'Province_State', 'state', 'name']].sample(10))
# Out:
#           FIPS Province_State state                 name
# 72853    18037        Indiana    IN        Dubois County
# 958155   12091        Florida    FL      Okaloosa County
# 1146045  51119       Virginia    VA     Middlesex County
# 1068649  28049    Mississippi    MS         Hinds County
# 755606   36081       New York    NY        Queens County
# 3014965  17199       Illinois    IL    Williamson County
# 1351096  51650       Virginia    VA         Hampton city
# 910537   46003   South Dakota    SD        Aurora County
# 313675   40125       Oklahoma    OK  Pottawatomie County
# 2003009  20207         Kansas    KS       Woodson County

# %%
missing_fips = df_us[df_us['state'].isna()]
print(missing_fips[['FIPS', 'Province_State']])
# Out:
#           FIPS Province_State
# 52       80001        Alabama
# 64       90001        Alabama
# 83        2158         Alaska
# 93       90002         Alaska
# 108      80004        Arizona
# ...        ...            ...
# 3020601  90051       Virginia
# 3020646  90053     Washington
# 3020700  90054  West Virginia
# 3020770  90055      Wisconsin
# 3020802  90056        Wyoming
#
# [141783 rows x 2 columns]

# %%
missing_fips = df_us[df_us['FIPS'].isna()]
print("Total rows with missing FIPS:", len(missing_fips))
print(missing_fips[['Province_State', 'Country_Region', 'state']].head(10))
# Out:
# Total rows with missing FIPS: 10583
#      Province_State Country_Region state
# 1249  Massachusetts             US   NaN
# 1284       Michigan             US   NaN
# 1316       Michigan             US   NaN
# 1569       Missouri             US   NaN
# 2444      Recovered             US   NaN
# 2917           Utah             US   NaN
# 2918           Utah             US   NaN
# 2922           Utah             US   NaN
# 2923           Utah             US   NaN
# 2926           Utah             US   NaN

# %%
state_abbr_map = {
    "Alabama": "AL", "Alaska": "AK", "Arizona": "AZ", "Arkansas": "AR", "California": "CA",
    "Colorado": "CO", "Connecticut": "CT", "Delaware": "DE", "Florida": "FL", "Georgia": "GA",
    "Hawaii": "HI", "Idaho": "ID", "Illinois": "IL", "Indiana": "IN", "Iowa": "IA", "Kansas": "KS",
    "Kentucky": "KY", "Louisiana": "LA", "Maine": "ME", "Maryland": "MD", "Massachusetts": "MA",
    "Michigan": "MI", "Minnesota": "MN", "Mississippi": "MS", "Missouri": "MO", "Montana": "MT",
    "Nebraska": "NE", "Nevada": "NV", "New Hampshire": "NH", "New Jersey": "NJ", "New Mexico": "NM",
    "New York": "NY", "North Carolina": "NC", "North Dakota": "ND", "Ohio": "OH", "Oklahoma": "OK",
    "Oregon": "OR", "Pennsylvania": "PA", "Rhode Island": "RI", "South Carolina": "SC",
    "South Dakota": "SD", "Tennessee": "TN", "Texas": "TX", "Utah": "UT", "Vermont": "VT",
    "Virginia": "VA", "Washington": "WA", "West Virginia": "WV", "Wisconsin": "WI", "Wyoming": "WY"
}

# %%
print("Is state_abbr_map True?", "state_abbr_map" in globals())
# Out:
# Is state_abbr_map True? True

# %%
print(df_us[['Province_State']].drop_duplicates().head(10))

df_us['state'] = df_us.apply(
    lambda row: state_abbr_map.get(row['Province_State'], row['state']) if pd.notna(row['Province_State']) else row['state'],
    axis=1
)
# Out:
#            Province_State
# 0                 Alabama
# 69                 Alaska
# 98                Arizona
# 115              Arkansas
# 191            California
# 250              Colorado
# 316           Connecticut
# 325              Delaware
# 329      Diamond Princess
# 330  District of Columbia

# %%
unwanted_entries = ["Diamond Princess", "Grand Princess", "District of Columbia"]

df_us = df_us[~df_us['Province_State'].isin(unwanted_entries)].copy()

# %%
missing_fips = df_us[df_us['FIPS'].isna()]
print("Total rows with missing FIPS:", len(missing_fips))
print(missing_fips[['Province_State', 'Country_Region', 'state']].head(10))
# Out:
# Total rows with missing FIPS: 10583
#      Province_State Country_Region state
# 1249  Massachusetts             US    MA
# 1284       Michigan             US    MI
# 1316       Michigan             US    MI
# 1569       Missouri             US    MO
# 2444      Recovered             US   NaN
# 2917           Utah             US    UT
# 2918           Utah             US    UT
# 2922           Utah             US    UT
# 2923           Utah             US    UT
# 2926           Utah             US    UT

# %%
valid_states = set(state_abbr_map.keys())

# %%
df_us = df_us[df_us['Province_State'].isin(valid_states)].copy()

# %%
print("Remaining unique Province_State values:")
print(df_us['Province_State'].drop_duplicates().sort_values())
# Out:
# Remaining unique Province_State values:
# 0              Alabama
# 69              Alaska
# 98             Arizona
# 115           Arkansas
# 191         California
# 250           Colorado
# 316        Connecticut
# 325           Delaware
# 331            Florida
# 399            Georgia
# 562             Hawaii
# 568              Idaho
# 613           Illinois
# 717            Indiana
# 810               Iowa
# 910             Kansas
# 1016          Kentucky
# 1137         Louisiana
# 1203             Maine
# 1221          Maryland
# 1246     Massachusetts
# 1260          Michigan
# 1347         Minnesota
# 1435       Mississippi
# 1518          Missouri
# 1635           Montana
# 1692          Nebraska
# 1786            Nevada
# 1804     New Hampshire
# 1815        New Jersey
# 1837        New Mexico
# 1871          New York
# 1935    North Carolina
# 2036      North Dakota
# 2091              Ohio
# 2180          Oklahoma
# 2259            Oregon
# 2296      Pennsylvania
# ...

# %%
missing_fips = df_us[df_us['FIPS'].isna()]
print("Total rows with missing FIPS:", len(missing_fips))
print(missing_fips[['Province_State', 'Country_Region', 'state']].head(10))
# Out:
# Total rows with missing FIPS: 9622
#      Province_State Country_Region state
# 1249  Massachusetts             US    MA
# 1284       Michigan             US    MI
# 1316       Michigan             US    MI
# 1569       Missouri             US    MO
# 2917           Utah             US    UT
# 2918           Utah             US    UT
# 2922           Utah             US    UT
# 2923           Utah             US    UT
# 2926           Utah             US    UT
# 2930           Utah             US    UT

# %%
missing_states = df_us[df_us['state'].isna()]
print("Total rows with missing state:", len(missing_states))
# Out:
# Total rows with missing state: 0

# %%
print(df_us.columns)
# Out:
# Index(['FIPS', 'Admin2', 'Province_State', 'Country_Region', 'Last_Update',
#        'Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'Combined_Key', 'Incident_Rate', 'Case_Fatality_Ratio', 'Date', 'state',
#        'name'],
#       dtype='object')

# %%
print("Total number of rows:", df_us.shape[0])
# Out:
# Total number of rows: 2948527

# %%
print(df_us.columns)
# Out:
# Index(['FIPS', 'Admin2', 'Province_State', 'Country_Region', 'Last_Update',
#        'Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'Combined_Key', 'Incident_Rate', 'Case_Fatality_Ratio', 'Date', 'state',
#        'name'],
#       dtype='object')

# %%
missing_name = df_us[df_us['name'].isna()]
print("Total rows with missing name:", len(missing_name))
# Out:
# Total rows with missing name: 70439

# %%
missing_fips = df_us[df_us['FIPS'].isna()]
print("Total rows with missing FIPS:", len(missing_fips))
# Out:
# Total rows with missing FIPS: 9622

# %%
df_us.head()
# Out:
#    FIPS   Admin2 Province_State Country_Region          Last_Update  \
# 0  1001  Autauga        Alabama             US  2021-01-02 05:22:33
# 1  1003  Baldwin        Alabama             US  2021-01-02 05:22:33
# 2  1005  Barbour        Alabama             US  2021-01-02 05:22:33
# 3  1007     Bibb        Alabama             US  2021-01-02 05:22:33
# 4  1009   Blount        Alabama             US  2021-01-02 05:22:33
#
#          Lat      Long_  Confirmed  Deaths  Recovered   Active  \
# 0  32.539527 -86.644082     4239.0    50.0        0.0   4189.0
# 1  30.727750 -87.722071    13823.0   169.0        0.0  13654.0
# 2  31.868263 -85.387129     1517.0    33.0        0.0   1484.0
# 3  32.996421 -87.125115     1854.0    46.0        0.0   1808.0
# 4  33.982109 -86.567906     4693.0    63.0        0.0   4630.0
#
#            Combined_Key  Incident_Rate  Case_Fatality_Ratio       Date state  \
# 0  Autauga, Alabama, US    7587.391935             1.179523 2021-01-01    AL
# ...

# %%
missing_admin = df_us[df_us['Admin2'].isna()]
print("Total rows with missing Admin2:", len(missing_admin))
# Out:
# Total rows with missing Admin2: 0

# %%
missing_name = df_us[df_us['name'].isna()]
print("Total rows with missing name:", len(missing_name))
print(missing_name[['Admin2', 'Province_State', 'state']].drop_duplicates().head(20))
# Out:
# Total rows with missing name: 70439
#          Admin2 Province_State state
# 52    Out of AL        Alabama    AL
# 64   Unassigned        Alabama    AL
# 83     Kusilvak         Alaska    AK
# 93   Unassigned         Alaska    AK
# 108   Out of AZ        Arizona    AZ
# 112  Unassigned        Arizona    AZ
# 184  Unassigned       Arkansas    AR
# 246  Unassigned     California    CA
# 297   Out of CO       Colorado    CO
# 312  Unassigned       Colorado    CO
# 323  Unassigned    Connecticut    CT
# 328  Unassigned       Delaware    DE
# 393  Unassigned        Florida    FL
# 508   Out of GA        Georgia    GA
# 543  Unassigned        Georgia    GA
# 566   Out of HI         Hawaii    HI
# 567  Unassigned         Hawaii    HI
# 610  Unassigned          Idaho    ID
# 684   Out of IL       Illinois    IL
# 704  Unassigned       Illinois    IL

# %%
df_us = df_us[~df_us['Admin2'].str.contains('Unassigned|Out of', na=False)].copy()

# %%
missing_name = df_us[df_us['name'].isna()]
print("Total rows with missing name:", len(missing_name))
print(missing_name[['Admin2', 'Province_State', 'state']].drop_duplicates().head(20))
# Out:
# Total rows with missing name: 12849
#                                            Admin2 Province_State state
# 83                                       Kusilvak         Alaska    AK
# 1249                          Dukes and Nantucket  Massachusetts    MA
# 1284       Federal Correctional Institution (FCI)       Michigan    MI
# 1316    Michigan Department of Corrections (MDOC)       Michigan    MI
# 1569                                  Kansas City       Missouri    MO
# 2548                                Oglala Lakota   South Dakota    SD
# 2917                                   Bear River           Utah    UT
# 2918                                 Central Utah           Utah    UT
# 2922                               Southeast Utah           Utah    UT
# 2923                               Southwest Utah           Utah    UT
# 2926                                    TriCounty           Utah    UT
# 2930                                 Weber-Morgan           Utah    UT
# ...

# %%
missing_fips = df_us[df_us['FIPS'].isna()]
print("Total rows with missing FIPS:", len(missing_fips))
print(missing_name[['Admin2', 'Province_State', 'state']].drop_duplicates().head(20))
# Out:
# Total rows with missing FIPS: 9276
#                                            Admin2 Province_State state
# 83                                       Kusilvak         Alaska    AK
# 1249                          Dukes and Nantucket  Massachusetts    MA
# 1284       Federal Correctional Institution (FCI)       Michigan    MI
# 1316    Michigan Department of Corrections (MDOC)       Michigan    MI
# 1569                                  Kansas City       Missouri    MO
# 2548                                Oglala Lakota   South Dakota    SD
# 2917                                   Bear River           Utah    UT
# 2918                                 Central Utah           Utah    UT
# 2922                               Southeast Utah           Utah    UT
# 2923                               Southwest Utah           Utah    UT
# 2926                                    TriCounty           Utah    UT
# 2930                                 Weber-Morgan           Utah    UT
# ...

# %%
custom_fips_map = {
    "Kusilvak": "02158",
    "Dukes and Nantucket": "25007",
    "Federal Correctional Institution (FCI)": "00000",
    "Michigan Department of Corrections (MDOC)": "00000",
    "Kansas City": "29510",
    "Oglala Lakota": "46102",
    "Bear River": "49003",
    "Central Utah": "49023",
    "Southeast Utah": "49037",
    "Southwest Utah": "49053",
    "TriCounty": "49047",
    "Weber-Morgan": "49057",
    "Copper River": "02066",
    "Chugach": "02063",
    "Desoto": "12027",
    "LeSeur": "27079",
    "Nashua": "33011"
}

# %%
df_us['FIPS'] = df_us.apply(
    lambda row: custom_fips_map.get(row['Admin2'], row['FIPS']),
    axis=1
)

# %%
missing_fips = df_us[df_us['FIPS'].isna()]
print("Total rows with missing FIPS:", len(missing_fips))
print(missing_name[['Admin2', 'Province_State', 'state']].drop_duplicates().head(20))
# Out:
# Total rows with missing FIPS: 180
#                                            Admin2 Province_State state
# 83                                       Kusilvak         Alaska    AK
# 1249                          Dukes and Nantucket  Massachusetts    MA
# 1284       Federal Correctional Institution (FCI)       Michigan    MI
# 1316    Michigan Department of Corrections (MDOC)       Michigan    MI
# 1569                                  Kansas City       Missouri    MO
# 2548                                Oglala Lakota   South Dakota    SD
# 2917                                   Bear River           Utah    UT
# 2918                                 Central Utah           Utah    UT
# 2922                               Southeast Utah           Utah    UT
# 2923                               Southwest Utah           Utah    UT
# 2926                                    TriCounty           Utah    UT
# 2930                                 Weber-Morgan           Utah    UT
# ...

# %%
df_us = df_us[~df_us['Admin2'].str.contains('Out-of-state|Unknown', na=False)].copy()

# %%
missing_fips = df_us[df_us['FIPS'].isna()]
print("Total rows with missing FIPS:", len(missing_fips))
print(missing_name[['Admin2', 'Province_State', 'state']].drop_duplicates().head(20))
# Out:
# Total rows with missing FIPS: 178
#                                            Admin2 Province_State state
# 83                                       Kusilvak         Alaska    AK
# 1249                          Dukes and Nantucket  Massachusetts    MA
# 1284       Federal Correctional Institution (FCI)       Michigan    MI
# 1316    Michigan Department of Corrections (MDOC)       Michigan    MI
# 1569                                  Kansas City       Missouri    MO
# 2548                                Oglala Lakota   South Dakota    SD
# 2917                                   Bear River           Utah    UT
# 2918                                 Central Utah           Utah    UT
# 2922                               Southeast Utah           Utah    UT
# 2923                               Southwest Utah           Utah    UT
# 2926                                    TriCounty           Utah    UT
# 2930                                 Weber-Morgan           Utah    UT
# ...

# %%
custom_fips_map.update({
    "Brockton": "25023",  
    "Out-of-state": "00000",  
    "Unknown": "00000", 
})

# %%
df_us['FIPS'] = df_us.apply(
    lambda row: custom_fips_map.get(row['Admin2'], row['FIPS']),
    axis=1
)

# %%
missing_fips = df_us[df_us['FIPS'].isna()]
print("Total rows with missing FIPS:", len(missing_fips))
print(missing_name[['Admin2', 'Province_State', 'state']].drop_duplicates().head(20))
# Out:
# Total rows with missing FIPS: 177
#                                            Admin2 Province_State state
# 83                                       Kusilvak         Alaska    AK
# 1249                          Dukes and Nantucket  Massachusetts    MA
# 1284       Federal Correctional Institution (FCI)       Michigan    MI
# 1316    Michigan Department of Corrections (MDOC)       Michigan    MI
# 1569                                  Kansas City       Missouri    MO
# 2548                                Oglala Lakota   South Dakota    SD
# 2917                                   Bear River           Utah    UT
# 2918                                 Central Utah           Utah    UT
# 2922                               Southeast Utah           Utah    UT
# 2923                               Southwest Utah           Utah    UT
# 2926                                    TriCounty           Utah    UT
# 2930                                 Weber-Morgan           Utah    UT
# ...

# %%
df_us = df_us.dropna(subset=['FIPS']).copy()

# %%
missing_fips_after = df_us[df_us['FIPS'].isna()]
print("Total rows still missing FIPS after dropping:", len(missing_fips_after))
# Out:
# Total rows still missing FIPS after dropping: 0

# %%
print(df_us.isnull().sum())
# Out:
# FIPS                         0
# Admin2                       0
# Province_State               0
# Country_Region               0
# Last_Update                  0
# Lat                          0
# Long_                        0
# Confirmed                    0
# Deaths                       0
# Recovered              1979339
# Active                 1979339
# Combined_Key                 0
# Incident_Rate                0
# Case_Fatality_Ratio     700137
# Date                         0
# state                        0
# name                     12670
# dtype: int64

# %%
print(df_us.isnull().sum() / len(df) * 100)
# Out:
# FIPS                    0.000000
# Admin2                  0.000000
# Province_State          0.000000
# Country_Region          0.000000
# Last_Update             0.000000
# Lat                     0.000000
# Long_                   0.000000
# Confirmed               0.000000
# Deaths                  0.000000
# Recovered              53.782601
# Active                 53.782601
# Combined_Key            0.000000
# Incident_Rate           0.000000
# Case_Fatality_Ratio    19.024123
# Date                    0.000000
# state                   0.000000
# name                    0.344269
# dtype: float64

# %%
df_us = df_us.dropna(subset=['Confirmed', 'Deaths']).copy()

# %%
print(df_us[['Confirmed', 'Deaths']].isna().sum())
# Out:
# Confirmed    0
# Deaths       0
# dtype: int64

# %%
df_us = df_us.dropna(subset=['name']).copy()

# %%
print(df_us[['name']].isna().sum())
# Out:
# name    0
# dtype: int64

# %%
df_us = df_us.dropna(subset=['Recovered', 'Active']).copy()

# %%
print(df_us.isnull().sum() / len(df) * 100)
# Out:
# FIPS                    0.00000
# Admin2                  0.00000
# Province_State          0.00000
# Country_Region          0.00000
# Last_Update             0.00000
# Lat                     0.00000
# Long_                   0.00000
# Confirmed               0.00000
# Deaths                  0.00000
# Recovered               0.00000
# Active                  0.00000
# Combined_Key            0.00000
# Incident_Rate           0.00000
# Case_Fatality_Ratio    18.91212
# Date                    0.00000
# state                   0.00000
# name                    0.00000
# dtype: float64

# %%
df_us['Case_Fatality_Ratio'] = df_us['Case_Fatality_Ratio'].fillna((df_us['Deaths'] / df_us['Confirmed']) * 100)

# %%
print(df_us.isnull().sum() / len(df) * 100)
# Out:
# FIPS                   0.0000
# Admin2                 0.0000
# Province_State         0.0000
# Country_Region         0.0000
# Last_Update            0.0000
# Lat                    0.0000
# Long_                  0.0000
# Confirmed              0.0000
# Deaths                 0.0000
# Recovered              0.0000
# Active                 0.0000
# Combined_Key           0.0000
# Incident_Rate          0.0000
# Case_Fatality_Ratio    0.5198
# Date                   0.0000
# state                  0.0000
# name                   0.0000
# dtype: float64

# %%
df_us = df_us.dropna(subset=['Case_Fatality_Ratio']).copy()

# %%
print(df_us.isnull().sum() / len(df) * 100)
# Out:
# FIPS                   0.0
# Admin2                 0.0
# Province_State         0.0
# Country_Region         0.0
# Last_Update            0.0
# Lat                    0.0
# Long_                  0.0
# Confirmed              0.0
# Deaths                 0.0
# Recovered              0.0
# Active                 0.0
# Combined_Key           0.0
# Incident_Rate          0.0
# Case_Fatality_Ratio    0.0
# Date                   0.0
# state                  0.0
# name                   0.0
# dtype: float64

# %%
df_us.to_csv('Kiana_cleaned_covid19_daily_reports_US.csv', index=False)

# %%
print("Yayayayaya")
# Out:
# Yayayayaya
